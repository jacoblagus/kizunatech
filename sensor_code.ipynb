# %%
import pandas as pd

bucket='kizsensordata'
data_key = 'datatraining.txt'
data_location = 's3://{}/{}'.format(bucket, data_key)

data1 = pd.read_csv(data_location, header=0, index_col=1, parse_dates=True, squeeze=True)

# %%
data_key2 = 'datatest.txt'
data_location2 = 's3://{}/{}'.format(bucket, data_key2)

data2 = pd.read_csv(data_location2, header=0, index_col=1, parse_dates=True, squeeze=True)

# %%
data_key3 = 'datatest2.txt'
data_location3 = 's3://{}/{}'.format(bucket, data_key3)

data3 = pd.read_csv(data_location3, header=0, index_col=1, parse_dates=True, squeeze=True)

# %%
import matplotlib.pyplot as pyplot
n_features = data1.values.shape[1]
pyplot.figure()
for i in range(1, n_features):
	# specify the subpout
	pyplot.subplot(n_features, 1, i)
	# plot data from each set
	pyplot.plot(data1.index, data1.values[:, i])
	pyplot.plot(data2.index, data2.values[:, i])
	pyplot.plot(data3.index, data3.values[:, i])
	# add a readable name to the plot
	pyplot.title(data1.columns[i], y=0.5, loc='right')
pyplot.show()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
data = pd.concat([data1, data2, data3])
# save aggregated dataset
data.to_csv('combined.csv')

# %%
data = pd.read_csv('combined.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
values = data.values
# split data into inputs and outputs
X, y = values[:, :-1], values[:, -1]
# split the dataset
from sklearn.model_selection import train_test_split
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=1)

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score

# make a naive prediction
def naive_prediction(testX, value):
	return [value for x in range(len(testX))]
 
# evaluate skill of predicting each class value
for value in [0, 1]:
	# forecast
	yhat = naive_prediction(testX, value)
	# evaluate
	score = accuracy_score(testy, yhat)
	# summarize
	print('Naive=%d score=%.3f' % (value, score))
# Out:
# Naive=0 score=0.822
# Naive=1 score=0.178

# %%
# logistic regression
from pandas import read_csv
# from sklearn.metrics import accuracy_score
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
# load the dataset
data = read_csv('combined.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
values = data.values
# split data into inputs and outputs
X, y = values[:, :-1], values[:, -1]
# split the dataset
trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=1)
# define the model
model = LogisticRegression()
# fit the model on the training set
model.fit(trainX, trainy)
# predict the test set
yhat = model.predict(testX)
# evaluate model skill
score = accuracy_score(testy, yhat)
print(score)
# Out:
# 0.9941634241245136
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# More EDA - Summary Statistics
display(data.describe())
# Out:
#                date   Temperature      Humidity         Light           CO2  \
# count  20560.000000  20560.000000  20560.000000  20560.000000  20560.000000
# mean    4116.576070     20.906212     27.655925    130.756622    690.553276
# std     2684.372188      1.055315      4.982154    210.430875    311.201281
# min        1.000000     19.000000     16.745000      0.000000    412.750000
# 25%     1760.000000     20.200000     24.500000      0.000000    460.000000
# 50%     3808.000000     20.700000     27.290000      0.000000    565.416667
# 75%     6378.000000     21.525000     31.290000    301.000000    804.666667
# max     9752.000000     24.408333     39.500000   1697.250000   2076.500000
#
#        HumidityRatio     Occupancy
# count   20560.000000  20560.000000
# mean        0.004228      0.231031
# std         0.000768      0.421503
# min         0.002674      0.000000
# 25%         0.003719      0.000000
# 50%         0.004292      0.000000
# 75%         0.004832      0.000000
# max         0.006476      1.000000

# %%
import numpy as np
a = np.array(data).astype('float32')
labels = a[:,6]

# %%
import sagemaker
import boto3

sess = sagemaker.Session()
prefix = "sagemaker/grades"

# %%
import io
import sagemaker.amazon.common as smac
import os

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, a, labels)
buf.seek(0)

key = 'linearlearner'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# uploaded training data location: s3://kizsensordata/sagemaker/grades/train/linearlearner
# training artifacts will be uploaded to: s3://kizsensordata/sagemaker/grades/output

# %%
 containers = {
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/linear-learner:latest'
              }
    
#containers[boto3.Session().region_name]

# %%
linear = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                       role = sagemaker.get_execution_role(), 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)

# %%
# This is for 'dim' down below = 7
print(data.shape)
# Out:
# (20560, 7)

# %%
# %%time
linear.set_hyperparameters(feature_dim=7,
                           mini_batch_size=200,
                           predictor_type='binary_classifier')

linear.fit({'train': s3_train_data})
# Out:
# 2020-07-02 14:46:49 Starting - Starting the training job...
# 2020-07-02 14:46:51 Starting - Launching requested ML instances......
# 2020-07-02 14:47:54 Starting - Preparing the instances for training......
# 2020-07-02 14:48:55 Downloading - Downloading input data...
# 2020-07-02 14:49:45 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [07/02/2020 14:49:47 INFO 140019182729024] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/02/2020 14:49:47 INFO 140019182729024] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'7', u'mini_batch_size': u'200', u'predictor_type': u'binary_classifier'}
# [07/02/2020 14:49:47 INFO 140019182729024] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'7', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'200', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/02/2020 14:49:47 WARNING 140019182729024] Loggers have already been setup.
# Process 1 is a worker.
# [07/02/2020 14:49:47 INFO 140019182729024] Using default worker.
# [07/02/2020 14:49:47 INFO 140019182729024] Checkpoint loading and saving are disabled.
# [2020-07-02 14:49:47.781] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 18, "num_examples": 1, "num_bytes": 14400}
# [07/02/2020 14:49:47 INFO 140019182729024] Create Store: local
# [2020-07-02 14:49:47.917] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 135, "num_examples": 51, "num_bytes": 734400}
# [07/02/2020 14:49:47 INFO 140019182729024] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f5870a38190>
# [07/02/2020 14:49:47 INFO 140019182729024] Scaling model computed with parameters:
#  {'stdev_weight':
# [2.4166479e+03 1.0832657e+00 5.0930548e+00 2.0663684e+02 3.1790140e+02
#  8.2225847e-04 4.3193191e-01]
# <NDArray 7 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
#

#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6675891445197311, "sum": 0.6675891445197311, "min": 0.6675891445197311}}, "EndTime": 1593701394.821861, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1593701394.821844}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6904186116012873, "sum": 0.6904186116012873, "min": 0.6904186116012873}}, "EndTime": 1593701394.821928, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1593701394.821911}
#
# [07/02/2020 14:49:54 INFO 140019182729024] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.184946734952
# [07/02/2020 14:49:54 INFO 140019182729024] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0118421994937
# [07/02/2020 14:49:54 INFO 140019182729024] Epoch 1: Loss improved. Updating best model
# [07/02/2020 14:49:54 INFO 140019182729024] Saving model for epoch: 1
# [07/02/2020 14:49:54 INFO 140019182729024] Saved checkpoint to "/tmp/tmp8fpfkH/mx-mod-0000.params"
# [07/02/2020 14:49:54 INFO 140019182729024] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 103, "sum": 103.0, "min": 103}, "Number of Batches Since Last Reset": {"count": 1, "max": 103, "sum": 103.0, "min": 103}, "Number of Records Since Last Reset": {"count": 1, "max": 20560, "sum": 20560.0, "min": 20560}, "Total Batches Seen": {"count": 1, "max": 258, "sum": 258.0, "min": 258}, "Total Records Seen": {"count": 1, "max": 51520, "sum": 51520.0, "min": 51520}, "Max Records Seen Between Resets": {"count": 1, "max": 20560, "sum": 20560.0, "min": 20560}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1593701394.830045, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1593701391.306014}
#
# [07/02/2020 14:49:54 INFO 140019182729024] #throughput_metric: host=algo-1, train throughput=5834.03739039 records/second
# [2020-07-02 14:49:58.052] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 3222, "num_examples": 103, "num_bytes": 1480320}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12602183846866383, "sum": 0.12602183846866383, "min": 0.12602183846866383}}, "EndTime": 1593701398.053122, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.05302}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11540590211456897, "sum": 0.11540590211456897, "min": 0.11540590211456897}}, "EndTime": 1593701398.053223, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053201}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1377872127645156, "sum": 0.1377872127645156, "min": 0.1377872127645156}}, "EndTime": 1593701398.053297, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053279}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12507091739598442, "sum": 0.12507091739598442, "min": 0.12507091739598442}}, "EndTime": 1593701398.053368, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.05335}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006335527329687394, "sum": 0.006335527329687394, "min": 0.006335527329687394}}, "EndTime": 1593701398.053444, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053425}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005905488623287894, "sum": 0.005905488623287894, "min": 0.005905488623287894}}, "EndTime": 1593701398.053519, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053499}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00638815731978884, "sum": 0.00638815731978884, "min": 0.00638815731978884}}, "EndTime": 1593701398.053593, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053575}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0056001523561666116, "sum": 0.0056001523561666116, "min": 0.0056001523561666116}}, "EndTime": 1593701398.053665, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053648}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.13385118879523933, "sum": 0.13385118879523933, "min": 0.13385118879523933}}, "EndTime": 1593701398.053728, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053711}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11531459371248881, "sum": 0.11531459371248881, "min": 0.11531459371248881}}, "EndTime": 1593701398.053791, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053773}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.13719007118075502, "sum": 0.13719007118075502, "min": 0.13719007118075502}}, "EndTime": 1593701398.053853, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053837}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12228755263721242, "sum": 0.12228755263721242, "min": 0.12228755263721242}}, "EndTime": 1593701398.053912, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053898}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02113866414801747, "sum": 0.02113866414801747, "min": 0.02113866414801747}}, "EndTime": 1593701398.053961, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.053945}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.02311669345872075, "sum": 0.02311669345872075, "min": 0.02311669345872075}}, "EndTime": 1593701398.054035, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1593701398.054017}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.
[tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 294, "num_examples": 103, "num_bytes": 1480320}
# [2020-07-02 14:50:37.399] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 293, "num_examples": 103, "num_bytes": 1480320}
# [07/02/2020 14:50:37 INFO 140019182729024] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.000673330997992017)
# [07/02/2020 14:50:37 INFO 140019182729024] #train_score (algo-1) : ('binary_classification_accuracy', 0.9987354085603113)
# [07/02/2020 14:50:37 INFO 140019182729024] #train_score (algo-1) : ('binary_f_1.000', 0.9972556470339877)
# [07/02/2020 14:50:37 INFO 140019182729024] #train_score (algo-1) : ('precision', 1.0)
# [07/02/2020 14:50:37 INFO 140019182729024] #train_score (algo-1) : ('recall', 0.9945263157894737)
# [07/02/2020 14:50:37 INFO 140019182729024] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.000673330997992
# [07/02/2020 14:50:37 INFO 140019182729024] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.99873540856
# [07/02/2020 14:50:37 INFO 140019182729024] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.997255647034
# [07/02/2020 14:50:37 INFO 140019182729024] #quality_metric: host=algo-1, train precision <score>=1.0
# [07/02/2020 14:50:37 INFO 140019182729024] #quality_metric: host=algo-1, train recall <score>=0.994526315789
# [07/02/2020 14:50:37 INFO 140019182729024] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [07/02/2020 14:50:37 INFO 140019182729024] Saved checkpoint to "/tmp/tmpc6zi1v/mx-mod-0000.params"
# [07/02/2020 14:50:37 INFO 140019182729024] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 49727.69594192505, "sum": 49727.69594192505, "min": 49727.69594192505}, "finalize.time": {"count": 1, "max": 613.2431030273438, "sum": 613.2431030273438, "min": 613.2431030273438}, "initialize.time": {"count": 1, "max": 261.9509696960449, "sum": 261.9509696960449, "min": 261.9509696960449}, "check_early_stopping.time": {"count": 15, "max": 1.0151863098144531, "sum": 14.002084732055664, "min": 0.8618831634521484}, "setuptime": {"count": 1, "max": 25.961875915527344, "sum": 25.961875915527344, "min": 25.961875915527344}, "update.time": {"count": 15, "max": 3521.6050148010254, "sum": 48712.83507347107, "min": 3140.571117401123}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1593701437.406352, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1593701387.762193}
#
#
# 2020-07-02 14:50:48 Uploading - Uploading generated training model
# 2020-07-02 14:50:48 Completed - Training job completed
# Training seconds: 113
# Billable seconds: 113
# CPU times: user 593 ms, sys: 28.6 ms, total: 622 ms
# Wall time: 4min 12s

# %%
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# -------------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %%
result = linear_predictor.predict(a[0])
print(result)
# Out:
# {'predictions': [{'score': 0.9984032511711121, 'predicted_label': 1}]}

# %%
a[0]
# Out:
# array([1.0000000e+00, 2.3180000e+01, 2.7271999e+01, 4.2600000e+02,
#        7.2125000e+02, 4.7929883e-03, 1.0000000e+00], dtype=float32)

# %% [markdown]
# # Train data, Test data

# %%
#train_data, test_data = np.split(data.sample(frac=1, random_state=1729), [int(0.7 * len(data))])
#print(train_data.shape, test_data.shape)

# %%
#result2 = linear_predictor.predict(test_data[0])
#print(result2)
#test_data[0]
